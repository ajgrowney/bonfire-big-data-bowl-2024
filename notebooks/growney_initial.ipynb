# %% [markdown]
# # Initial Exploration the Data Given

# %%
import os
import pandas as pd

# %%
DATA_ROOT = os.environ["BIG_DATA_BOWL_ROOT"]

# %% [markdown]
# ## Checkout the Out of Game Data

# %%
plays = pd.read_csv(f"{DATA_ROOT}/plays.csv")

# %%
plays.columns
# Out:
# Index(['gameId', 'playId', 'ballCarrierId', 'ballCarrierDisplayName',
#        'playDescription', 'quarter', 'down', 'yardsToGo', 'possessionTeam',
#        'defensiveTeam', 'yardlineSide', 'yardlineNumber', 'gameClock',
#        'preSnapHomeScore', 'preSnapVisitorScore', 'passResult', 'passLength',
#        'penaltyYards', 'prePenaltyPlayResult', 'playResult',
#        'playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation',
#        'defendersInTheBox', 'passProbability', 'preSnapHomeTeamWinProbability',
#        'preSnapVisitorTeamWinProbability', 'homeTeamWinProbabilityAdded',
#        'visitorTeamWinProbilityAdded', 'expectedPoints', 'expectedPointsAdded',
#        'foulName1', 'foulName2', 'foulNFLId1', 'foulNFLId2'],
#       dtype='object')

# %%
plays[[
    "gameId", "gameClock", "down", "yardsToGo", "yardlineNumber",
    "possessionTeam", "playResult", "ballCarrierDisplayName",
    "passResult", "passLength", "passProbability",
    "offenseFormation", "defendersInTheBox",
    "expectedPoints", "expectedPointsAdded"]].head(25)
# Out:
#         gameId gameClock  down  yardsToGo  yardlineNumber possessionTeam  \
# 0   2022100908      7:52     1         10              41            ATL
# 1   2022091103      7:38     1         10              34            PIT
# 2   2022091111      8:57     2          5              30             LV
# 3   2022100212     13:12     2         10              37            DEN
# 4   2022091900      8:33     1         10              35            BUF
# 5   2022103001     10:14     3         17              18            ATL
# 6   2022100207     13:31     3          5              25            TEN
# 7   2022102310     15:00     1         10              25             SF
# 8   2022102310     10:31     1         10              40             KC
# 9   2022092511      0:35     1         10              25            SEA
# 10  2022091112     13:44     3          1              27             GB
# 11  2022110606      4:47     3          3              12            NYJ
# 12  2022091102     11:55     3         10              25             SF
# 13  2022103010      5:35     3         16              15             LA
# 14  2022102304     11:30     4          1              20            JAX
# 15  2022100212      8:50     3         16              18            DEN
# 16  2022102303     13:04     2          9              19            DAL
# 17  2022110603      5:02     2          9              37            DET
# 18  2022103001      4:56     3          2               2            CAR
# 19  2022100211      0:07     1         10              35             GB
# 20  2022100910      6:24     1         10              50            CAR
# 21  2022102305     12:35     3         15              33            IND
# 22  2022092504     11:03     1         10              38            MIN
# 23  2022101601      7:27     1         10              25            CLE
# 24  2022102306     13:23     1         10              17            WAS
#
#     playResult ballCarrierDisplayName passResult  passLength  passProbability  \
# 0            9           Parker Hesse          C         6.0         0.747284
# 1            3         Chase Claypool        NaN         NaN         0.416454
# 2           15          Darren Waller          C        11.0         0.267933
# 3            7             Mike Boone        NaN         NaN         0.592704
# 4            3       Devin Singletary        NaN         NaN         0.470508
# 5            5         Tyler Allgeier          C        -5.0         0.908870
# 6            3         Ryan Tannehill          R         NaN         0.973272
# 7            7         Jeffery Wilson        NaN         NaN         0.497866
# 8            9        Jerick McKinnon        NaN         NaN         0.496857
# 9            3          Rashaad Penny          C        -5.0         0.604374
# 10           3            A.J. Dillon        NaN         NaN         0.337682
# 11           5            Zach Wilson          R         NaN         0.880266
# 12          11           Ross Dwelley          C        11.0         0.976593
# 13           6      Darrell Henderson        NaN         NaN         0.975052
# 14           0        Trevor Lawrence        NaN         NaN         0.153301
# 15           9       Courtland Sutton          C         9.0         0.927468
# 16          10            CeeDee Lamb          C         6.0         0.706215
# 17           8          Kalif Raymond          C        -2.0         0.501552
# 18           2         D'Onta Foreman        NaN         NaN         0.757645
# 19           6           Allen Lazard          C        -2.0         0.941940
# 20           2    Christian McCaffrey        NaN         NaN         0.537104
# 21           7        Michael Pittman          C         7.0         0.970585
# 22           7            Dalvin Cook        NaN         NaN         0.597950
# 23           8             Nick Chubb        NaN         NaN         0.520626
# 24           2         Brian Robinson        NaN         NaN         0.601351
#
#    offenseFormation  defendersInTheBox  expectedPoints  expectedPointsAdded
# 0           SHOTGUN                7.0        2.360609             0.981955
# 1           SHOTGUN                7.0        1.733344            -0.263424
# 2            I_FORM                6.0        1.312855             1.133666
# 3        SINGLEBACK                6.0        1.641006            -0.043580
# 4            I_FORM                7.0        3.686428            -0.167903
# 5           SHOTGUN                5.0       -1.484904            -0.639661
# 6             EMPTY                4.0        0.137272            -1.269624
# 7        SINGLEBACK                7.0        1.298699             0.282340
# 8           SHOTGUN                6.0        1.827773             0.733410
# 9           SHOTGUN                7.0        0.986438            -0.477845
# 10          SHOTGUN                6.0        1.084807             0.506989
# 11          SHOTGUN                6.0        4.453594             1.200647
# 12          SHOTGUN                6.0       -0.208933             1.777092
# 13          SHOTGUN                5.0       -1.245599            -0.218564
# 14           I_FORM                9.0        2.986392            -4.255993
# 15          SHOTGUN                6.0        2.996730            -0.132424
# 16          SHOTGUN                7.0        0.165307             1.392677
# 17          SHOTGUN                6.0        1.173901             0.660732
# 18          SHOTGUN                8.0        5.080226             1.919774
# 19          SHOTGUN                3.0        0.185777            -0.185777
# 20       SINGLEBACK                7.0        3.031909            -0.444478
# 21          SHOTGUN                6.0       -0.231656            -0.617905
# 22           I_FORM                7.0        2.136666             0.512122
# 23          SHOTGUN                7.0        1.372455             0.408110
# 24          SHOTGUN                6.0        0.748630            -0.457978
